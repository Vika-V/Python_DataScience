# %% [markdown]
# # Python Functions and Linear Regression Basics
# Vika Vijayanand

# %% [markdown]
# ## 1
# #### Define a function called “calculate si amount” that takes the parameters “principal”, “rate”, and “time” and computes the “interest” using the formula
#               interest = principal*rate*time/100,
# #### (1) and returns the variable “total” computed by adding “principal” and “rate”. Next, call the
# function using the values principal = 1859, rate = 1.67, and time = 5

# %%
def calculate_si_amount(principle, rate, time):
    interest = (principle*rate*time)/100
    total = principle + interest
    return total
calculate_si_amount(1859, 1.67, 5)

# %% [markdown]
# ## 2
# #### Define a function called “calculate sum’ that takes a variable number of parameters and computed their sum. Make sure you initialize your starting sum correctly and return the final result to a variable called “ sum”. Finally, compute the same of the numbers 34, 73.8, 28 and 78.

# %%
def calculate_sum(x, *args):
    sum = x 
    for arg in args:
        sum = sum+ arg
    return sum
calculate_sum(34, 73.8, 28, 78)
# Out:
# 213.8

# %% [markdown]
# ## 3
# #### Import the public “diabetes” database from the sklearn library and save it to a dataframe called “diabetes”. Print to screen the shape of the dataset and the first ten lines of the dataset. Next, perform a simple linear regression using only the variable “Age” to predict the variable “Body mass index”. Save your model in a variable called “simple prediction”. Print to screen the intercept and the coefficients obtained from your linear regression model and the score of your prediction.

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
data = load_diabetes()
diabetes = pd.DataFrame(data.data, columns = data.feature_names)
diabetes.shape
diabetes.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# ...

# %%
from sklearn import linear_model
X = diabetes[['age']]
Y = diabetes['bmi']
simple_prediction = linear_model.LinearRegression()
simple_prediction.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(simple_prediction.intercept_)
print(simple_prediction.coef_)
# Out:
# -7.34031317064707e-16
# [0.18508467]

# %% [markdown]
# ## 4
#
# ##### Import the public “diabetes” database from the sklearn library and save it to a dataframe called “diabetes”. Next, perform a multiple linear regression using the variables “Age”, “Body mass index” to predict the variable “Average blood pressure”. Save your model in a variable called “multiple prediction”. Print to screen the intercept and the coefficients obtained from your linear regression model and the score of your prediction.

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
data = load_diabetes()
diabetes = pd.DataFrame(data.data, columns = data.feature_names)
diabetes.shape
diabetes.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# ...

# %%
X = diabetes[['age', 'bmi']]
Y = diabetes['bp']
multiple_prediction = linear_model.LinearRegression()
multiple_prediction.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(multiple_prediction.intercept_)
print(multiple_prediction.coef_)
# Out:
# 5.053591186760818e-16
# [0.27154348 0.34515679]

# %% [markdown]
# ## 5
#
# Define the following dataset
#
#    Assign it to a dataframe
# of the dataset and print to screen the first 5 rows. Using the “statsmodel” library, compute a simple linear regression using the values in “Year” to predict “Bedrooms” and assign it to a variable called “model”. Print to screen the summary of your result.

# %%
import numpy as np
import statsmodels.api as sm
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

Housing = { 'Year' : [2017, 2017, 2017, 2017, 2018, 2018, 2018, 2019, 2019],
            'Income(K)': [67, 78, 69, 130, 95, 113, 99, 178, 156],
            'Bedrooms' : [2,1,1,2,2,2, 3, 4, 3],
            'Bathrooms' : [1,1, 2, 2, 1, 2, 1, 3, 2]}
df = pd.DataFrame(Housing, columns= ['Year', 'Income(K)', 'Bedrooms', 'Bathrooms'])
df.head(5)
# Out:
#    Year  Income(K)  Bedrooms  Bathrooms
# 0  2017         67         2          1
# 1  2017         78         1          1
# 2  2017         69         1          2
# 3  2017        130         2          2
# 4  2018         95         2          1

# %%
X = Housing['Year']
Y = Housing['Bedrooms']
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.706
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     16.82
# Date:                Sat, 29 Aug 2020   Prob (F-statistic):            0.00456
# Time:                        16:20:50   Log-Likelihood:                -6.4717
# No. Observations:                   9   AIC:                             16.94
# Df Residuals:                       7   BIC:                             17.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1975.2000    482.100     -4.097      0.005   -3115.185    -835.215
# ...

# %% [markdown]
# ## 6
# #### Consider the dataframe “df’ created in the previous question. Using the “statsmodel” library, compute a simple linear regression using the values in “Year” and “Income (K)” to predict “Bedrooms” and assign it to a variable called “multiple model”. Print to screen the summary of your result.

# %%
X= df[['Year', 'Income(K)']]
Y =  df['Bedrooms']
X = sm.add_constant(X)
multiple_model = sm.OLS(Y, X).fit()
print(multiple_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Bedrooms   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     9.382
# Date:                Sat, 29 Aug 2020   Prob (F-statistic):             0.0142
# Time:                        16:21:05   Log-Likelihood:                -5.6040
# No. Observations:                   9   AIC:                             17.21
# Df Residuals:                       6   BIC:                             17.80
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1245.0799    800.834     -1.555      0.171   -3204.651     714.491
# ...

# %% [markdown]
# ####
